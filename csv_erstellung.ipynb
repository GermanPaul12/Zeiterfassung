# %%
import pandas as pd
import numpy as np
import datetime as dt


def daterange(date1, date2):
    for n in range(int ((date2 - date1).days)+1):
        yield date1 + dt.timedelta(n)

dates = [dtt.strftime('%Y-%m-%d') for dtt in daterange(dt.datetime.strptime(f"{dt.datetime.now().year-2}-01-01", "%Y-%m-%d"),
                                                                                             dt.datetime.strptime("2025-09-30", "%Y-%m-%d"))]

kommen = [dt.datetime.strptime('08:00', '%H:%M') for i in range(len(dates))]
pause = [dt.datetime.strptime('0:30', '%H:%M') for i in range(len(dates))]
gehen = [dt.datetime.strptime('16:30', '%H:%M') if i % 3 != 0 else dt.datetime.strptime('15:30', '%H:%M') for i in range(len(dates))]   

weekday = [dt.datetime.strptime(date, '%Y-%m-%d').weekday() for date in dates]
dict_wochentag = {0:'Montag', 1:'Dienstag', 2:'Mittwoch', 3:'Donnerstag', 4:'Freitag', 5:'Samstag', 6:'Sonntag'}
wochentag = [dict_wochentag[i] for i in weekday]

dict_data = {'Datum':dates, 'Kommen':kommen, 'Pause':pause, 'Gehen':gehen}


df = pd.DataFrame(dict_data)
df['Wochentag'] = wochentag
df
# Out:
#            Datum              Kommen               Pause               Gehen  \
# 0     2020-01-01 1900-01-01 08:00:00 1900-01-01 00:30:00 1900-01-01 15:30:00
# 1     2020-01-02 1900-01-01 08:00:00 1900-01-01 00:30:00 1900-01-01 16:30:00
# 2     2020-01-03 1900-01-01 08:00:00 1900-01-01 00:30:00 1900-01-01 16:30:00
# 3     2020-01-04 1900-01-01 08:00:00 1900-01-01 00:30:00 1900-01-01 15:30:00
# 4     2020-01-05 1900-01-01 08:00:00 1900-01-01 00:30:00 1900-01-01 16:30:00
# ...          ...                 ...                 ...                 ...
# 2095  2025-09-26 1900-01-01 08:00:00 1900-01-01 00:30:00 1900-01-01 16:30:00
# 2096  2025-09-27 1900-01-01 08:00:00 1900-01-01 00:30:00 1900-01-01 16:30:00
# 2097  2025-09-28 1900-01-01 08:00:00 1900-01-01 00:30:00 1900-01-01 15:30:00
# 2098  2025-09-29 1900-01-01 08:00:00 1900-01-01 00:30:00 1900-01-01 16:30:00
# 2099  2025-09-30 1900-01-01 08:00:00 1900-01-01 00:30:00 1900-01-01 16:30:00
#
#        Wochentag
# 0       Mittwoch
# ...

# %%
df['Summe'] = pd.to_timedelta(df.Gehen.strftime('%H:%M')) - pd.to_timedelta(df.Kommen.dt.strftime('%H:%M')) - pd.to_timedelta(df.Pause.dt.strftime('%H:%M'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [45], in <cell line: 1>()
# ----> 1 df['Summe'] = pd.to_timedelta(df.Gehen.strftime('%H:%M')) - pd.to_timedelta(df.Kommen.dt.strftime('%H:%M')) - pd.to_timedelta(df.Pause.dt.strftime('%H:%M'))
#
# File ~\Anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'strftime'

# %%
df.dtypes
# Out:
# Datum        datetime64[ns]
# Kommen       datetime64[ns]
# Pause        datetime64[ns]
# Gehen        datetime64[ns]
# Wochentag            object
# dtype: object

# %%
df['Datum'] = pd.to_datetime(df['Datum'])

# %%
df.dtypes
# Out:
# Datum        datetime64[ns]
# Kommen       datetime64[ns]
# Pause        datetime64[ns]
# Gehen        datetime64[ns]
# Wochentag            object
# dtype: object

# %%
kommen = ['08:00' for i in range(len(dates))]
pause = ['0:30' for i in range(len(dates))]
gehen = ['16:30' if i % 3 != 0 else '15:30' for i in range(len(dates))]

# %%
df = df[df['Wochentag'] != 'Samstag']
df = df[df['Wochentag'] != 'Sonntag']
df
# Out:
#            Datum              Kommen               Pause               Gehen  \
# 0     2020-01-01 1900-01-01 08:00:00 1900-01-01 00:30:00 1900-01-01 15:30:00
# 1     2020-01-02 1900-01-01 08:00:00 1900-01-01 00:30:00 1900-01-01 16:30:00
# 2     2020-01-03 1900-01-01 08:00:00 1900-01-01 00:30:00 1900-01-01 16:30:00
# 5     2020-01-06 1900-01-01 08:00:00 1900-01-01 00:30:00 1900-01-01 16:30:00
# 6     2020-01-07 1900-01-01 08:00:00 1900-01-01 00:30:00 1900-01-01 15:30:00
# ...          ...                 ...                 ...                 ...
# 2093  2025-09-24 1900-01-01 08:00:00 1900-01-01 00:30:00 1900-01-01 16:30:00
# 2094  2025-09-25 1900-01-01 08:00:00 1900-01-01 00:30:00 1900-01-01 15:30:00
# 2095  2025-09-26 1900-01-01 08:00:00 1900-01-01 00:30:00 1900-01-01 16:30:00
# 2098  2025-09-29 1900-01-01 08:00:00 1900-01-01 00:30:00 1900-01-01 16:30:00
# 2099  2025-09-30 1900-01-01 08:00:00 1900-01-01 00:30:00 1900-01-01 16:30:00
#
#        Wochentag
# 0       Mittwoch
# ...

# %%
dates = [dtt.strftime('%Y-%m-%d') for dtt in daterange(dt.datetime.strptime(f"{dt.datetime.now().year-2}-01-03", "%Y-%m-%d"),
                                                                                             dt.datetime.strptime("2025-09-30", "%Y-%m-%d"))]

kommen = ['08:00' for i in range(len(dates))]
pause = ['0:30' for i in range(len(dates))]
gehen = ['16:30' if i % 7 != 0 else '15:30' for i in range(len(dates))]    
soll_zeit = ['08:00' if i % 7 != 0 else '07:00' for i in range(len(dates))]  
ist_zeit = ['08:00' if i % 7 != 0 else '07:00' for i in range(len(dates))]
zeitkonto = ['00:00' for i in range(len(dates))]

weekday = [dt.datetime.strptime(date, '%Y-%m-%d').weekday() for date in dates]
dict_wochentag = {0:'Montag', 1:'Dienstag', 2:'Mittwoch', 3:'Donnerstag', 4:'Freitag', 5:'Samstag', 6:'Sonntag'}
wochentag = [dict_wochentag[i] for i in weekday]

dict_data = {'Datum':dates, 'Kommen':kommen, 'Pause':pause, 'Gehen':gehen, 'Soll_Zeit':soll_zeit, 'Ist_Zeit':ist_zeit, 'Zeitkonto':zeitkonto}

df = pd.DataFrame(dict_data)
df['Wochentag'] = wochentag
df['Datum'] = pd.to_datetime(df['Datum'])
df = df[df['Wochentag'] != 'Samstag']
df = df[df['Wochentag'] != 'Sonntag']
df['Datum'] = pd.to_datetime(df['Datum'])

def timedelta_calc(kommen, gehen, pause):
    
    if kommen[0] == '0':
        zeit_kommen_stunden = int(kommen[1])
        zeit_kommen_minuten = int(kommen[3:5])
    else:
        zeit_kommen_stunden = int(kommen[0:2])
        zeit_kommen_minuten = int(kommen[3:5])
    
    if gehen[0] == '0':
        zeit_gehen_stunden = int(gehen[1])
        zeit_gehen_minuten = int(gehen[3:5])
    else:
        zeit_gehen_stunden = int(gehen[0:2])
        zeit_gehen_minuten = int(gehen[3:5]) 
    
    pause = int(pause[3:5])
    
    zeit_stunden = zeit_gehen_stunden - zeit_kommen_stunden    
    
    if zeit_gehen_minuten + 60 < zeit_kommen_minuten + pause:
        zeit_minuten = 120 + zeit_gehen_minuten - zeit_kommen_minuten
        zeit_stunden -= 2
    elif zeit_gehen_minuten < zeit_kommen_minuten + pause:
        zeit_minuten = 60 + zeit_gehen_minuten - zeit_kommen_minuten
        zeit_stunden -= 1
    else: 
        zeit_minuten = zeit_gehen_minuten - zeit_kommen_minuten + 30   
        if zeit_minuten == 60:
            zeit_minuten = '00'
            zeit_stunden += 1
    return f"{zeit_stunden}:{zeit_minuten}"    
    
    
print(timedelta_calc(df.Kommen[0], df.Gehen[0], df.Pause[0]))       
df[['Kommen','Pause', 'Gehen', 
       'Soll_Zeit', 'Ist_Zeit', 'Zeitkonto']] = df[['Kommen','Pause', 'Gehen',
                                                    'Soll_Zeit', 'Ist_Zeit', 'Zeitkonto']].apply(pd.to_datetime)
# Out:
# 8:00

# %%
460 % 60
# Out:
# 40

# %%
print(len(f'{460 % 60}'))
print(f'{460 % 60}')

print(len(f'{420 % 60}'))
print(f'{420 % 60}')
# Out:
# 2
# 40
# 1
# 0

# %%
def timedelta_calc(kommen, gehen, pause):
    
    #ALle Zeiten in Integer umrechnen
    if kommen[0] == '0':
        print('Kommen')
        zeit_kommen_stunden = int(kommen[1])
        zeit_kommen_minuten = int(kommen[3:5])
    else:
        print('Kommen2')
        zeit_kommen_stunden = int(kommen[0:2])
        zeit_kommen_minuten = int(kommen[3:5])
    
    if gehen[0] == '0':
        print('Gehen')
        zeit_gehen_stunden = int(gehen[1])
        zeit_gehen_minuten = int(gehen[3:5])
    else:
        print('Gehen2')
        zeit_gehen_stunden = int(gehen[0:2])
        zeit_gehen_minuten = int(gehen[3:5]) 
    
    pause = int(pause[3:5])
    
    #Pause von der Gehen Zeit abziehen
    if zeit_gehen_minuten - pause < 0:
        print('Pause')
        zeit_gehen_minuten = 60 + zeit_gehen_minuten - pause
        zeit_gehen_stunden -= 1
    else:
        print('Pause2')
        zeit_gehen_minuten -= pause
    
    #Die Stunden ausrechnen wie lange ich da war
    
    zeit_stunden = zeit_gehen_stunden - zeit_kommen_stunden    
    
    #Die Minuten ausrechnen wie lang ich da war
    
    if zeit_gehen_minuten - zeit_kommen_minuten < 0:
        print('Zeit')
        zeit_minuten = 60 + zeit_gehen_minuten - zeit_kommen_minuten
        zeit_stunden -= 1
    else:
        print('Zeit2')
        zeit_minuten = zeit_gehen_minuten - zeit_kommen_minuten
    
    if len(str(zeit_minuten)) == 1:
        zeit_minuten = f'0{zeit_minuten}'
                
    if len(str(zeit_stunden)) == 1:
        return f"0{zeit_stunden}:{zeit_minuten}" 
    
    return f"{zeit_stunden}:{zeit_minuten}"  


def zeitkonto_calc(ist_zeit, soll_zeit):

    ist_zeit_stunden = int(ist_zeit[0:2])
    ist_zeit_minuten = int(ist_zeit[3:5])
    
    soll_zeit_stunden = int(soll_zeit[0:2])
    soll_zeit_minuten = int(soll_zeit[3:5])
    
    
    if ist_zeit_stunden < soll_zeit_stunden:
        if ist_zeit_minuten > soll_zeit_minuten:
            zeit_stunden = f'0{abs(int(ist_zeit_stunden + 1 - soll_zeit_stunden))}'
            zeit_minuten = f'{ist_zeit_minuten - soll_zeit_minuten}'
                    
            if len(zeit_minuten) == 1:
                zeit_minuten = f'0{zeit_minuten}'
            if int(zeit_stunden) == 0:
                return f"{zeit_stunden}:{zeit_minuten}"
            return f"-{zeit_stunden}:{zeit_minuten}"
        else:    
            zeit_stunden = f'{ist_zeit_stunden - soll_zeit_stunden}'
            zeit_minuten = f'{ist_zeit_minuten - soll_zeit_minuten}'
            if int(zeit_stunden) < 10:
                zeit_stunden = f'0{abs(int(zeit_stunden))}'
            if len(zeit_minuten) == 1:
                zeit_minuten = f'0{zeit_minuten}'    
            return f"-{zeit_stunden}:{zeit_minuten}"
    else: 
        zeit_stunden = f'{ist_zeit_stunden - soll_zeit_stunden}'
        zeit_minuten = f'{ist_zeit_minuten - soll_zeit_minuten}'
        if len(zeit_stunden) == 1:
            zeit_stunden = f'0{zeit_stunden}'
        if len(zeit_minuten) == 1:
            zeit_minuten = f'0{zeit_minuten}' 
        return f" {zeit_stunden}:{zeit_minuten}"

    
def zeitkonto_insgesamt(zeitkonto):
    zeit = 0
    for i in range(len(zeitkonto)):
        #if zeitkonto[i] != '00:00':
            #print(zeitkonto[i])
        if zeitkonto[i][0] == ' ':
            zeitkonto_std = int(zeitkonto[i][0:3])
            zeitkonto_min = int(zeitkonto[i][4:6])
       
        elif zeitkonto[i][0] == '-':  
            zeitkonto_std = int(zeitkonto[i][0:3])
            zeitkonto_min = int(f'-{zeitkonto[i][4:6]}')
            
        else:
            zeitkonto_std = int(zeitkonto[i][0:2])
            zeitkonto_min = int(zeitkonto[i][3:5])          
        if zeitkonto_min >= 0:
            zeit += zeitkonto_std * 60 + zeitkonto_min
        else: 
            zeit -= (zeitkonto_min + 60 * zeitkonto_std)          
    if zeit >= 60:
        zeit_min = f'{zeit % 60}'
        if len(zeit_min) == 1:
            zeit_min = f'0{zeit_min}'
        zeit_std = f' {(zeit - int(zeit_min)) // 60}'
        if len(zeit_std) == 1:
            zeit_std = f'0{zeit_std}'
        return f' {zeit_std}:{zeit_min}'

# %%
df = pd.read_csv('C:/Users/paulg/Documents/Coding/Zeiterfassung/full_data.csv')
df['Ist_Zeit'] = [timedelta_calc(df.Kommen[i], df.Gehen[i], df.Pause[i]) for i in range(len(df.Datum))]
df['Zeitkonto'] = [zeitkonto_calc(df.Ist_Zeit[i], df.Soll_Zeit[i]) for i in range(len(df.Datum))]
for i in range(5):
    print(i)
    print(timedelta_calc(df.Kommen[i], df.Gehen[i], df.Pause[i]))
    print(df.Kommen[i], df.Gehen[i], df.Pause[i])
#print(zeitkonto_insgesamt(df['Zeitkonto']))
# Out:
# Kommen
# Gehen2
# Pause2
# Zeit2
# Kommen
# Gehen2
# Pause2
# Zeit2
# Kommen
# Gehen2
# Pause2
# Zeit2
# Kommen
# Gehen2
# Pause2
# Zeit2
# Kommen
# Gehen2
# Pause2
# Zeit2
# Kommen
# Gehen2
# Pause2
# Zeit2
# Kommen
# Gehen2
# Pause2
# Zeit2
# Kommen
# Gehen2
# Pause2
# Zeit2
# Kommen
# Gehen2
# Pause2
# Zeit2
# Kommen
# Gehen2
# Pause2
# Zeit2
# Kommen
# Gehen2
# Pause2
# Zeit2
# Kommen
# Gehen2
# Pause2
# Zeit2
# Kommen
# Gehen2
# Pause2
# Zeit2
# Kommen
# Gehen2
# Pause2
# Zeit2
# Kommen
# Gehen2
# Pause2
# Zeit2
# Kommen
# Gehen2
# Pause2
# Zeit2
# Kommen
# Gehen2
# Pause2
# Zeit2
# Kommen
# Gehen2
# Pause2
# Zeit2
# Kommen
# Gehen2
# Pause2
# Zeit2
# Kommen
# Gehen2
# Pause2
# Zeit2
# Kommen
# Gehen2
# Pause2
# Zeit2
# Kommen
# Gehen2
# Pause2
# Zeit2
# Kommen
# Gehen2
# Pause2
# Zeit2
# Kommen
# Gehen2
# Pause2
# Zeit2
# Kommen
# Gehen2
# Pause2
# Zeit2
# Kommen
# Gehen2
# Pause2
# Zeit2
# Kommen
# Gehen2
# Pause2
# Zeit2
# Kommen
# Gehen2
# Pause2
# Zeit2
# Kommen
# Gehen2
# ...

# %%
print("zeitkonto_calc('08:00', '07:00')")
print(zeitkonto_calc('08:00', '07:00'))

print("zeitkonto_calc('08:40', '08:00')")
print(zeitkonto_calc('08:40', '08:00'))

print("zeitkonto_calc('07:00', '08:00')")
print(zeitkonto_calc('07:00', '08:00'))

print("zeitkonto_calc('07:30', '08:00')")
print(zeitkonto_calc('07:30', '08:00'))

print("zeitkonto_calc('09:30', '08:00')")
print(zeitkonto_calc('09:30', '08:00'))

print("zeitkonto_calc('06:30', '08:00')")
print(zeitkonto_calc('06:30', '08:00'))

print("zeitkonto_calc('05:30', '08:00')")
print(zeitkonto_calc('05:30', '08:00'))
# Out:
# zeitkonto_calc('08:00', '07:00')
#  01:00
# zeitkonto_calc('08:40', '08:00')
#  00:40
# zeitkonto_calc('07:00', '08:00')
# -01:00
# zeitkonto_calc('07:30', '08:00')
# 00:30
# zeitkonto_calc('09:30', '08:00')
#  01:30
# zeitkonto_calc('06:30', '08:00')
# -01:30
# zeitkonto_calc('05:30', '08:00')
# -02:30

# %%
print("timedelta_calc('08:00', '16:30', '00:30')")
print(timedelta_calc('08:00', '16:30', '00:30'))

print("timedelta_calc('07:50', '16:00', '00:30')")
print(timedelta_calc('07:50', '16:00', '00:30'))

print("timedelta_calc('07:50', '18:10', '00:40')")
print(timedelta_calc('07:50', '18:10', '00:40'))

print("timedelta_calc('07:30', '16:00', '00:30')")
print(timedelta_calc('07:30', '16:00', '00:30'))

print("timedelta_calc('07:10', '16:00', '00:40')")
print(timedelta_calc('07:10', '16:00', '00:40'))
# Out:
# timedelta_calc('08:00', '16:30', '00:30')
# 08:00
# timedelta_calc('07:50', '16:00', '00:30')
# 07:40
# timedelta_calc('07:50', '18:10', '00:40')
# 09:40
# timedelta_calc('07:30', '16:00', '00:30')
# 08:00
# timedelta_calc('07:10', '16:00', '00:40')
# 08:10
